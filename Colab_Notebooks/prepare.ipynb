# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/mypythondirectory')

# %%
import os
os.chdir("/content/drive/MyDrive/MTech_Project_Code/")
# !ls
# Out:
# build_dataset.ipynb  model		    summarize_model.py
# build_dataset.py     my_model.pth	    train.ipynb
# config.py	     pr_curves.ipynb	    train.py
# data		     pr_curves.py	    Untitled.ipynb
# evaluate.ipynb	     __pycache__	    utils
# evaluate.py	     README.md		    visualize_model.ipynb
# GTSRB		     runs		    visualize_model.py
# lib		     summarize_model.ipynb

# %%
import cv2
import pickle
from model.net import net

# %%
pickle_out= open("my_model.pth","wb")  # wb = WRITE BYTE
pickle.dump(net,pickle_out)
pickle_out.close()
cv2.waitKey(1)
# Out:
# -1
